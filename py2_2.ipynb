# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('CSV/auto-mpg.csv')
plt.scatter(df.mpg,df.acceleration,marker='v',s=100,color='red')
plt.scatter(df.mpg,df.displacement,marker='*',s=100,color='blue')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('CSV/auto-mpg.csv')
# plt.plot(df.mpg,df.acceleration)
sns.regplot(x=df.mpg,y=df.acceleration)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('CSV/auto-mpg.csv')
# plt.plot(df.mpg,df.acceleration)
sns.regplot(x=df.mpg,y=df.acceleration,marker='v',scatter_kws={'color':'red','s':30,'alpha':0.7},
            line_kws={'color':'green','lw':2,'ls':':','alpha':0.2})
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df=pd.read_csv('CSV/auto-mpg.csv')
data = np.random.randint(low=1,high=100,size=(10,10))
# print(data)
sns.heatmap(data=df.corr(),annot=True,vmax=0.8,vmin=0.2,cmap='tab20',linewidths=2,linecolor='red',cbar=False)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pywaffle import Waffle
data = {'c':['A','B','C','D'],'v':[20,35,15,30]}
df=pd.DataFrame(data)
fig = plt.figure(FigureClass=Waffle,rows=10,values=df.v,labels=list(df.c),legend={'loc':'upper left'},characters='❤')
plt.title('B1 is best')
plt.show()
# Out:
# <Waffle size 432x288 with 1 Axes>

# %%
from wordcloud import WordCloud,STOPWORDS
stopwords=set(STOPWORDS)
print(stopwords)
# Out:
# {'against', 'i', 'very', 'under', 'until', 'after', "wasn't", 'their', 'does', "mustn't", "he'll", 'yours', "she'd", "you'll", 'whom', "she's", 'his', "isn't", "i'd", 'of', "there's", 'between', 'hence', "we'll", 'when', 'my', "how's", 'yourself', "shan't", "don't", 'before', 'who', 'all', 'r', 'other', "they're", 'by', 'since', 'both', 'therefore', "it's", 'these', 'being', 'few', "doesn't", 'doing', 'however', 'out', 'in', 'or', "we'd", 'only', 'some', "you've", 'am', 'from', 'off', "wouldn't", 'below', "they've", 'your', "hadn't", 'down', 'is', 'above', 'could', "that's", 'have', 'those', 'while', 'where', 'further', "why's", 'during', "i'm", "i'll", 'k', 'would', "i've", 'can', "what's", 'did', 'for', 'ourselves', 'me', 'nor', 'here', 'had', 'yourselves', 'ever', 'otherwise', 'how', 'own', 'should', 'ought', 'we', 'com', "they'd", 'just', 'than', 'as', 'they', 'was', 'himself', 'to', 'why', 'with', 'do', 'myself', 'again', 'not', 'be', 'on', 'has', 'each', 'if', 'also', 'get', 't
# ...

# %%
from wordcloud import WordCloud,STOPWORDS
import requests
url='https://www.gutenberg.org/files/11/11-0.txt'
response=requests.get(url)
text=response.text
print(text)
# Out:
# *** START OF THE PROJECT GUTENBERG EBOOK 11 ***
# [Illustration]
#
#
#
#
# Alice’s Adventures in Wonderland
#
# by Lewis Carroll
#
# THE MILLENNIUM FULCRUM EDITION 3.0
#
# Contents
#
#  CHAPTER I.     Down the Rabbit-Hole
#  CHAPTER II.    The Pool of Tears
#  CHAPTER III.   A Caucus-Race and a Long Tale
#  CHAPTER IV.    The Rabbit Sends in a Little Bill
#  CHAPTER V.     Advice from a Caterpillar
#  CHAPTER VI.    Pig and Pepper
#  CHAPTER VII.   A Mad Tea-Party
#  CHAPTER VIII.  The Queen’s Croquet-Ground
#  CHAPTER IX.    The Mock Turtle’s Story
#  CHAPTER X.     The Lobster Quadrille
#  CHAPTER XI.    Who Stole the Tarts?
#  CHAPTER XII.   Alice’s Evidence
#
#
#
#
# CHAPTER I.
# Down the Rabbit-Hole
#
#
# Alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into
# the book her sister was reading, but it had no pictures or
# conversations in it, “and what is the use of a book,” thought Alice
# ...

# %%
from wordcloud import WordCloud,STOPWORDS
import requests
url='https://www.gutenberg.org/files/11/11-0.txt'
stopwords=set(STOPWORDS)
response=requests.get(url)
text=response.text
alice_wc=WordCloud(background_color='white',max_words=2000,stopwords=stopwords)
alice_wc.generate(text)
plt.imshow(alice_wc)
plt.axis('off')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
g=nx.Graph()
# g=nx.DiGraph() For direction in graph
g.add_node(1)
g.add_node(2)
g.add_node(3)
g.add_edge(1,2)
g.add_edge(2,3)
g.add_edge(3,1)
nx.draw(g,with_labels=True)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
g=nx.DiGraph()
g.add_node(1)
g.add_nodes_from([2,3])
g.add_nodes_from(range(4,7))
g.add_edge(1,2)
g.add_edges_from([(2,3),(3,4),(4,5),(5,6),(6,1)])
nx.draw(g,with_labels=True)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
insta={'p1':[0,1,1,0,1],'p2':[0,0,1,0,1],'p3':[1,1,0,1,1],'p4':[1,1,1,0,0],'p5':[1,1,0,0,0]}
g=nx.DiGraph()
g.add_nodes_from(insta.keys())
for i,follower in enumerate(insta):
    for j,follow in enumerate(insta[follower]):
        if follow:
            g.add_edge(follower,list(insta.keys())[j])
nx.draw(g,with_labels=True,node_size=850,node_color='skyblue',width=5)
plt.show()
